# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharko123/AI_Lab_Hackathon/blob/main/AI_Lab_School_Hackathon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline
import seaborn as sns
import plotly.io as pio
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('train.csv')
center=pd.read_csv('fulfilment_center_info.csv')
meal=pd.read_csv('meal_info.csv')
test=pd.read_csv('test.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-26bbc7b90e61> in <cell line: 1>()
# ----> 1 data=pd.read_csv('train.csv')
#       2 center=pd.read_csv('fulfilment_center_info.csv')
#       3 meal=pd.read_csv('meal_info.csv')
#       4 test=pd.read_csv('test.csv')
#
# ...

# %%
data.head()
# Out:
#         id  week  center_id  meal_id  checkout_price  base_price  \
# 0  1379560   1.0       55.0   1885.0          136.83      152.29
# 1  1466964   1.0       55.0   1993.0          136.83      135.83
# 2  1346989   1.0       55.0   2539.0          134.86      135.86
# 3  1338232   1.0       55.0   2139.0          339.50      437.53
# 4  1448490   1.0       55.0   2631.0          243.50      242.50
#
#    emailer_for_promotion  homepage_featured  num_orders
# 0                    0.0                0.0       177.0
# 1                    0.0                0.0       270.0
# 2                    0.0                0.0       189.0
# 3                    0.0                0.0        54.0
# 4                    0.0                0.0        40.0

# %%
print("The Shape of Demand dataset :",data.shape)
print("The Shape of Fulmilment Center Information dataset :",center.shape)
print("The Shape of Meal information dataset :",meal.shape)
print("The Shape of Test dataset :",test.shape)
# Out:
# The Shape of Demand dataset : (129342, 9)
# The Shape of Fulmilment Center Information dataset : (77, 5)
# The Shape of Meal information dataset : (51, 3)
# The Shape of Test dataset : (32573, 8)

# %%
data.head()
# Out:
#         id  week  center_id  meal_id  checkout_price  base_price  \
# 0  1379560   1.0       55.0   1885.0          136.83      152.29
# 1  1466964   1.0       55.0   1993.0          136.83      135.83
# 2  1346989   1.0       55.0   2539.0          134.86      135.86
# 3  1338232   1.0       55.0   2139.0          339.50      437.53
# 4  1448490   1.0       55.0   2631.0          243.50      242.50
#
#    emailer_for_promotion  homepage_featured  num_orders
# 0                    0.0                0.0       177.0
# 1                    0.0                0.0       270.0
# 2                    0.0                0.0       189.0
# 3                    0.0                0.0        54.0
# 4                    0.0                0.0        40.0

# %%
center.head()
# Out:
#    center_id  city_code  region_code center_type  op_area
# 0         11        679           56      TYPE_A      3.7
# 1         13        590           56      TYPE_B      6.7
# 2        124        590           56      TYPE_C      4.0
# 3         66        648           34      TYPE_A      4.1
# 4         94        632           34      TYPE_C      3.6

# %%
meal.head()
# Out:
#    meal_id   category cuisine
# 0     1885  Beverages    Thai
# 1     1993  Beverages    Thai
# 2     2539  Beverages    Thai
# 3     1248  Beverages  Indian
# 4     2631  Beverages  Indian

# %%
data=data.merge(center,on='center_id',how='left')

# %%
data=data.merge(meal,on='meal_id',how='left')

# %%
print(set(data["category"]))
# Out:
# {nan, 'Starters', 'Beverages', 'Desert', 'Seafood', 'Other Snacks', 'Extras', 'Sandwich', 'Biryani', 'Soup', 'Pizza', 'Pasta', 'Salad', 'Rice Bowl'}

# %%
data.head()
# Out:
#         id  week  center_id  meal_id  checkout_price  base_price  \
# 0  1379560   1.0       55.0   1885.0          136.83      152.29
# 1  1466964   1.0       55.0   1993.0          136.83      135.83
# 2  1346989   1.0       55.0   2539.0          134.86      135.86
# 3  1338232   1.0       55.0   2139.0          339.50      437.53
# 4  1448490   1.0       55.0   2631.0          243.50      242.50
#
#    emailer_for_promotion  homepage_featured  num_orders  city_code  \
# 0                    0.0                0.0       177.0      647.0
# 1                    0.0                0.0       270.0      647.0
# 2                    0.0                0.0       189.0      647.0
# 3                    0.0                0.0        54.0      647.0
# 4                    0.0                0.0        40.0      647.0
#
#    region_code center_type  op_area   category cuisine
# 0         56.0      TYPE_C      2.0  Beverages    Thai
# 1         56.0      TYPE_C      2.0  Beverages    Thai
# ...

# %%
data.isna().sum()
# Out:
# id                       0
# week                     1
# center_id                1
# meal_id                  1
# checkout_price           1
# base_price               1
# emailer_for_promotion    1
# homepage_featured        1
# num_orders               1
# city_code                1
# region_code              1
# center_type              1
# op_area                  1
# category                 1
# cuisine                  1
# dtype: int64

# %%
data['discount amount']=data['base_price']-data['checkout_price']

# %%
data['discount percent'] = ((data['base_price']-data['checkout_price'])/data['base_price'])*100

# %%
data['discount y/n'] = [1 if x>0 else 0 for x in (data['base_price']-data['checkout_price'])]

# %%
data=data.sort_values(['meal_id', 'week']).reset_index()

# %%
city4={590:'CH1', 526:'CH2', 638:'CH3'}
data['city_enc_4']=data['city_code'].map(city4)
data['city_enc_4']=data['city_enc_4'].fillna('CH4')

# %%
print(set(data["city_enc_4"]))
# Out:
# {'CH2', 'CH4', 'CH1', 'CH3'}

# %%
data = data.drop(columns=['meal_id'])

# %%
data.head()
# Out:
#    index       id  week  checkout_price  base_price  emailer_for_promotion  \
# 0      7  1499955   1.0          182.36      183.36                    0.0
# 1     40  1351400   1.0          184.36      182.36                    0.0
# 2     84  1057835   1.0          184.36      182.36                    0.0
# 3    125  1231510   1.0          170.78      170.78                    0.0
# 4    164  1402151   1.0          175.60      174.60                    0.0
#
#    homepage_featured  num_orders   category  cuisine  discount amount  \
# 0                0.0       391.0  Beverages  Italian              1.0
# 1                0.0       514.0  Beverages  Italian             -2.0
# 2                0.0       798.0  Beverages  Italian             -2.0
# 3                0.0       284.0  Beverages  Italian              0.0
# 4                0.0       256.0  Beverages  Italian             -1.0
#
#    discount percent  discount y/n city_enc_4
# 0          0.545375             1        CH4
# ...

# %%
center.head()
# Out:
#    center_id  city_code  region_code center_type  op_area
# 0         11        679           56      TYPE_A      3.7
# 1         13        590           56      TYPE_B      6.7
# 2        124        590           56      TYPE_C      4.0
# 3         66        648           34      TYPE_A      4.1
# 4         94        632           34      TYPE_C      3.6

# %%
#data['center_id']=data['center_id'].astype('object')
#data['meal_id']=data['meal_id'].astype('object')
data['city_enc_4']=data['city_enc_4'].astype('object')
data['cuisine']=data['cuisine'].astype('object')
data['category']=data['category'].astype('object')

#data['region_code']=data['region_code'].astype('object')

# %%
data['city_enc_4']
# Out:
# 0         CH4
# 1         CH4
# 2         CH4
# 3         CH4
# 4         CH2
#          ...
# 129337    CH2
# 129338    CH4
# 129339    CH4
# 129340    CH4
# 129341    CH4
# Name: city_enc_4, Length: 129342, dtype: object

# %%
obj=data[['category','cuisine', 'city_enc_4']]

# %%
obj.head()
# Out:
#     category  cuisine city_enc_4
# 0  Beverages  Italian        CH4
# 1  Beverages  Italian        CH4
# 2  Beverages  Italian        CH4
# 3  Beverages  Italian        CH4
# 4  Beverages  Italian        CH2

# %%
encode1=pd.get_dummies(obj,drop_first = True)

# %%
num=data.drop(columns = ["city_enc_4"],axis=1)

# %%
data = pd.concat([num, encode1], axis = 1)

# %%
data = data.dropna()

# %%
X = data.drop(columns = ["num_orders", "id", "week", "cuisine", "category"])
y = data["num_orders"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
xgb = XGBRegressor(max_depth = 9,
    learning_rate=0.5,
        silent= 1,
        objective= 'reg:linear',
        eval_metric= 'rmse',
        seed= 4)

# %%
X_test = X_test.drop(columns = ["index"])

# %%
xgb.fit(X_train,y_train)
pred = xgb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
import xgboost as xgb

def objective(space):
    clf=xgb.XGBRegressor(
                    n_estimators =space['n_estimators'], max_depth = int(space['max_depth']), gamma = space['gamma'],
                    reg_alpha = int(space['reg_alpha']),min_child_weight=int(space['min_child_weight']),
                    colsample_bytree=int(space['colsample_bytree']))

    evaluation = [(X_train, y_train), (X_test, y_test)]

    clf.fit(X_train, y_train,
            eval_set=evaluation, eval_metric="auc",
            early_stopping_rounds=10,verbose=False)
    pred = clf.predict(X_test)
    return {'loss': mean_squared_error(y_test, pred), 'status': STATUS_OK }

# %%
from hyperopt import STATUS_OK, Trials, fmin, hp, tpe

space={'max_depth': hp.quniform("max_depth", 3, 18, 1),
        'gamma': hp.uniform ('gamma', 1,9),
        'reg_alpha' : hp.quniform('reg_alpha', 40,180,1),
        'reg_lambda' : hp.uniform('reg_lambda', 0,1),
        'colsample_bytree' : hp.uniform('colsample_bytree', 0.5,1),
        'min_child_weight' : hp.quniform('min_child_weight', 0, 10, 1),
        'n_estimators': 180,
        'seed': 0
       }
trials = Trials()
best_hyperparams = fmin(fn = objective,
                        space = space,
                        algo = tpe.suggest,
                        max_evals = 100,
                        trials = trials)
# Out:
# 100%|██████████| 100/100 [01:36<00:00,  1.04trial/s, best loss: 154278.9184200455]

# %%
print("The best hyperparameters are : ","\n")
print(best_hyperparams)
# Out:
# The best hyperparameters are :
#
# {'colsample_bytree': 0.7274888893804589, 'gamma': 5.9864222055450504, 'max_depth': 17.0, 'min_child_weight': 6.0, 'reg_alpha': 40.0, 'reg_lambda': 0.544469793515352}

# %%
xgb_goat = XGBRegressor(colsample_bytree = 0.7274888893804589, gamma = 5.9864222055450504, max_depth = 17, min_child_weight = 6.0, reg_alpha = 40, reg_lambda = 0.544469793515352)

# %%
xgb_goat.fit(X_train,y_train)
print(xgb_goat.score(X_test, y_test))
# Out:
# 0.6273730741907823

# %%
X_test
# Out:
#          index  checkout_price  base_price  emailer_for_promotion  \
# 90060    65567          253.20      254.20                    0.0
# 34270    24114          490.85      491.85                    0.0
# 124731   29304          233.77      284.27                    1.0
# 24121    21113          242.50      244.50                    0.0
# 91260   119552          248.32      249.32                    0.0
# ...        ...             ...         ...                    ...
# 89739   115413          484.03      620.86                    1.0
# 36214   100965          640.23      641.23                    0.0
# 78465   125528          309.43      309.43                    0.0
# 81177   122694          440.44      439.44                    0.0
# 110580   36043          243.53      241.53                    0.0
#
#         homepage_featured  discount amount  discount percent  discount y/n  \
# 90060                 0.0             1.00          0.393391             1
# ...

# %%
xgb_goat.predict([X_test])

# %%
import joblib

joblib.dump(xgb, "xgb_model.pkl")
# Out:
# ['xgb_model.pkl']

# %%
X_train.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2625f76b8a6d> in <cell line: 1>()
# ----> 1 X_train.columns
#
# NameError: name 'X_train' is not defined
